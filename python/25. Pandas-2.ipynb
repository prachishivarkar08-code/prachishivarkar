# %%
import pandas as pd

# %%
df_str = pd.DataFrame({
    'names': ['  Alice  ', 'BOB', 'charlie', 'DIANA'],
    'emails': ['alice@email.com', 'bob@COMPANY.COM', 'charlie@email.com', 'diana@company.com']
})

# %%
df_str
# Out:
#        names             emails
# 0    Alice      alice@email.com
# 1        BOB    bob@COMPANY.COM
# 2    charlie  charlie@email.com
# 3      DIANA  diana@company.com

# %%
# String methods (vectorized operations)
print(df_str['names'].str.lower())       # Convert to lowercase
# Out:
# 0      alice
# 1          bob
# 2      charlie
# 3        diana
# Name: names, dtype: object

# %%
print(df_str['names'].str.upper())       # Convert to uppercase
# Out:
# 0      ALICE
# 1          BOB
# 2      CHARLIE
# 3        DIANA
# Name: names, dtype: object

# %%
print(df_str['names'].str.title())       # Title case
# Out:
# 0      Alice
# 1          Bob
# 2      Charlie
# 3        Diana
# Name: names, dtype: object

# %%
print(df_str['names'].str.strip())       # Remove leading/trailing whitespace
# Out:
# 0      Alice
# 1        BOB
# 2    charlie
# 3      DIANA
# Name: names, dtype: object

# %%
print(df_str['names'].str.len())         # Length of strings
# Out:
# 0    9
# 1    3
# 2    7
# 3    5
# Name: names, dtype: int64

# %%
print(df_str['names'].str.replace(' ', '_'))   # Replace characters
print(df_str['emails'].str.split('@'))          # Split strings
# Out:
# 0    __Alice__
# 1          BOB
# 2      charlie
# 3        DIANA
# Name: names, dtype: object
# 0      [alice, email.com]
# 1      [bob, COMPANY.COM]
# 2    [charlie, email.com]
# 3    [diana, company.com]
# Name: emails, dtype: object

# %%
print(df_str['emails'].str.split('@', expand=True))  # Split into columns
# Out:
#          0            1
# 0    alice    email.com
# 1      bob  COMPANY.COM
# 2  charlie    email.com
# 3    diana  company.com

# %%
df_dup = pd.DataFrame({
    'A': [1, 2, 2, 3, 3, 3],
    'B': ['x', 'y', 'y', 'z', 'z', 'w'],
    'C': [10, 20, 20, 30, 30, 40]
})

# %%
df_dup
# Out:
#    A  B   C
# 0  1  x  10
# 1  2  y  20
# 2  2  y  20
# 3  3  z  30
# 4  3  z  30
# 5  3  w  40

# %%
df_dup.duplicated().sum()
# Out:
# 2

# %%
df_dup.drop_duplicates()
# Out:
#    A  B   C
# 0  1  x  10
# 1  2  y  20
# 3  3  z  30
# 5  3  w  40

# %%
df = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'Salary': [70000, 80000, 90000]
})

# %%
df
# Out:
#       Name  Age  Salary
# 0    Alice   25   70000
# 1      Bob   30   80000
# 2  Charlie   35   90000

# %%
df["newcol"] = "Null"

# %%
df
# Out:
#       Name  Age  Salary newcol
# 0    Alice   25   70000   Null
# 1      Bob   30   80000   Null
# 2  Charlie   35   90000   Null

# %%
df['Bonus'] = df['Salary'] * 0.1

# %%
df
# Out:
#       Name  Age  Salary newcol   Bonus
# 0    Alice   25   70000   Null  7000.0
# 1      Bob   30   80000   Null  8000.0
# 2  Charlie   35   90000   Null  9000.0

# %%
df.drop("newcol", axis = 1, inplace=True)

# %%
df
# Out:
#       Name  Age  Salary   Bonus
# 0    Alice   25   70000  7000.0
# 1      Bob   30   80000  8000.0
# 2  Charlie   35   90000  9000.0

# %%
df['Full_Info'] = df['Name'] + ' (' + df['Age'].astype(str) + ')'

# %%
df
# Out:
#       Name  Age  Salary   Bonus     Full_Info
# 0    Alice   25   70000  7000.0    Alice (25)
# 1      Bob   30   80000  8000.0      Bob (30)
# 2  Charlie   35   90000  9000.0  Charlie (35)

# %%
df = df.assign(
    Tax = df['Salary'] * 0.3,
    Net_Salary = lambda x: x['Salary'] - x['Tax']
)

# %%
df
# Out:
#       Name  Age  Salary   Bonus     Full_Info      Tax  Net_Salary
# 0    Alice   25   70000  7000.0    Alice (25)  21000.0     49000.0
# 1      Bob   30   80000  8000.0      Bob (30)  24000.0     56000.0
# 2  Charlie   35   90000  9000.0  Charlie (35)  27000.0     63000.0

# %%
df.insert(0, 'Employee_ID', ['E001', 'E002', 'E003'])

# %%
df
# Out:
#   Employee_ID     Name  Age  Salary   Bonus     Full_Info      Tax  Net_Salary
# 0        E001    Alice   25   70000  7000.0    Alice (25)  21000.0     49000.0
# 1        E002      Bob   30   80000  8000.0      Bob (30)  24000.0     56000.0
# 2        E003  Charlie   35   90000  9000.0  Charlie (35)  27000.0     63000.0

# %%
df.insert(3, 'Employee_ID1', ['E001', 'E002', 'E003'])

# %%
df
# Out:
#   Employee_ID     Name  Age Employee_ID1  Salary   Bonus     Full_Info  \
# 0        E001    Alice   25         E001   70000  7000.0    Alice (25)
# 1        E002      Bob   30         E002   80000  8000.0      Bob (30)
# 2        E003  Charlie   35         E003   90000  9000.0  Charlie (35)
#
#        Tax  Net_Salary
# 0  21000.0     49000.0
# 1  24000.0     56000.0
# 2  27000.0     63000.0

# %%
df_renamed = df.rename(columns={'Name': 'Employee_Name', 'Age': 'Employee_Age'})

# %%
df_renamed
# Out:
#   Employee_ID Employee_Name  Employee_Age Employee_ID1  Salary   Bonus  \
# 0        E001         Alice            25         E001   70000  7000.0
# 1        E002           Bob            30         E002   80000  8000.0
# 2        E003       Charlie            35         E003   90000  9000.0
#
#       Full_Info      Tax  Net_Salary
# 0    Alice (25)  21000.0     49000.0
# 1      Bob (30)  24000.0     56000.0
# 2  Charlie (35)  27000.0     63000.0

# %%
df_sort = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie', 'Diana'],
    'Age': [25, 35, 30, 28],
    'Salary': [70000, 90000, 80000, 75000],
    'Department': ['HR', 'IT', 'Finance', 'HR']
})

# %%
df_sort
# Out:
#       Name  Age  Salary Department
# 0    Alice   25   70000         HR
# 1      Bob   35   90000         IT
# 2  Charlie   30   80000    Finance
# 3    Diana   28   75000         HR

# %%
print(df_sort.sort_values('Age', ascending=False))
# Out:
#       Name  Age  Salary Department
# 1      Bob   35   90000         IT
# 2  Charlie   30   80000    Finance
# 3    Diana   28   75000         HR
# 0    Alice   25   70000         HR

# %%
print(df_sort.sort_values('Name', ascending=False))
# Out:
#       Name  Age  Salary Department
# 3    Diana   28   75000         HR
# 2  Charlie   30   80000    Finance
# 1      Bob   35   90000         IT
# 0    Alice   25   70000         HR

# %%
df_sales = pd.DataFrame({
    'Region': ['North', 'South', 'East', 'West', 'North', 'South', 'East', 'West'],
    'Product': ['A', 'A', 'B', 'B', 'A', 'B', 'A', 'B'],
    'Sales': [100, 150, 200, 120, 180, 160, 140, 190],
    'Profit': [20, 30, 40, 25, 35, 32, 28, 38],
    'Quarter': ['Q1', 'Q3', 'Q1', 'Q1', 'Q2', 'Q3', 'Q2', 'Q2']
})

# %%
df_sales
# Out:
#   Region Product  Sales  Profit Quarter
# 0  North       A    100      20      Q1
# 1  South       A    150      30      Q3
# 2   East       B    200      40      Q1
# 3   West       B    120      25      Q1
# 4  North       A    180      35      Q2
# 5  South       B    160      32      Q3
# 6   East       A    140      28      Q2
# 7   West       B    190      38      Q2

# %%
grouped = df_sales.groupby('Region')

# %%
list(grouped)
# Out:
# [('East',
#     Region Product  Sales  Profit Quarter
#   2   East       B    200      40      Q1
#   6   East       A    140      28      Q2),
#  ('North',
#     Region Product  Sales  Profit Quarter
#   0  North       A    100      20      Q1
#   4  North       A    180      35      Q2),
#  ('South',
#     Region Product  Sales  Profit Quarter
#   1  South       A    150      30      Q3
#   5  South       B    160      32      Q3),
#  ('West',
#     Region Product  Sales  Profit Quarter
#   3   West       B    120      25      Q1
#   7   West       B    190      38      Q2)]

# %%
print(grouped.sum())
# Out:
#        Product  Sales  Profit Quarter
# Region
# East        BA    340      68    Q1Q2
# North       AA    280      55    Q1Q2
# South       AB    310      62    Q3Q3
# West        BB    310      63    Q1Q2

# %%
print(grouped.count())
# Out:
#         Product  Sales  Profit  Quarter
# Region
# East          2      2       2        2
# North         2      2       2        2
# South         2      2       2        2
# West          2      2       2        2

# %%
multi_grouped = df_sales.groupby(['Region', 'Product'])

# %%
print(multi_grouped.sum())
# Out:
#                 Sales  Profit Quarter
# Region Product
# East   A          140      28      Q2
#        B          200      40      Q1
# North  A          280      55    Q1Q2
# South  A          150      30      Q3
#        B          160      32      Q3
# West   B          310      63    Q1Q2

# %%
print(df_sales.groupby('Region')['Sales'].sum())
# Out:
# Region
# East     340
# North    280
# South    310
# West     310
# Name: Sales, dtype: int64

# %%
print(df_sales.groupby('Product')[['Sales', "Profit"]].sum())
# Out:
#          Sales  Profit
# Product
# A          570     113
# B          670     135

# %%
df_sales
# Out:
#   Region Product  Sales  Profit Quarter
# 0  North       A    100      20      Q1
# 1  South       A    150      30      Q3
# 2   East       B    200      40      Q1
# 3   West       B    120      25      Q1
# 4  North       A    180      35      Q2
# 5  South       B    160      32      Q3
# 6   East       A    140      28      Q2
# 7   West       B    190      38      Q2

# %%
pivot_table = pd.pivot_table(df_sales, 
                           values='Sales', 
                           index='Region', 
                           columns='Product', 
                           aggfunc='sum',
                           fill_value=0)

# %%
pivot_table
# Out:
# Product    A    B
# Region
# East     140  200
# North    280    0
# South    150  160
# West       0  310

# %%
pivot_table = pd.pivot_table(df_sales, 
                           values='Sales', 
                           index='Region', 
                           columns='Quarter', 
                           aggfunc='sum',
                           fill_value=0)

# %%
pivot_table
# Out:
# Quarter   Q1   Q2   Q3
# Region
# East     200  140    0
# North    100  180    0
# South      0    0  310
# West     120  190    0

# %%
pivot_table = pd.pivot_table(df_sales, 
                           values='Profit', 
                           index='Product', 
                           columns='Quarter', 
                           aggfunc='sum',
                           fill_value=0)

# %%
pivot_table
# Out:
# Quarter  Q1  Q2  Q3
# Product
# A        20  63  30
# B        65  38  32

# %%
df1 = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
df2 = pd.DataFrame({'A': [7, 8, 9], 'B': [10, 11, 12]})
df3 = pd.DataFrame({'C': [13, 14, 15], 'D': [16, 17, 18]})

# %%
df1
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df2
# Out:
#    A   B
# 0  7  10
# 1  8  11
# 2  9  12

# %%
df3
# Out:
#     C   D
# 0  13  16
# 1  14  17
# 2  15  18

# %%
result_vertical = pd.concat([df1, df2])
print(result_vertical)
# Out:
#    A   B
# 0  1   4
# 1  2   5
# 2  3   6
# 0  7  10
# 1  8  11
# 2  9  12

# %%
result_horizontal = pd.concat([df1, df3], axis=1)
print(result_horizontal)
# Out:
#    A  B   C   D
# 0  1  4  13  16
# 1  2  5  14  17
# 2  3  6  15  18

# %%
result_reindex = pd.concat([df1, df2], ignore_index=True)
print(result_reindex)
# Out:
#    A   B
# 0  1   4
# 1  2   5
# 2  3   6
# 3  7  10
# 4  8  11
# 5  9  12

# %%
import numpy as np

# %%
date_range = pd.date_range('2023-01-01', periods=100, freq='D')
ts_data = pd.DataFrame({
    'date': date_range,
    'value': np.random.randn(100).cumsum(),
    'category': np.random.choice(['A', 'B', 'C'], 100)
})

# %%
date_range
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#                '2023-01-05', '2023-01-06', '2023-01-07', '2023-01-08',
#                '2023-01-09', '2023-01-10', '2023-01-11', '2023-01-12',
#                '2023-01-13', '2023-01-14', '2023-01-15', '2023-01-16',
#                '2023-01-17', '2023-01-18', '2023-01-19', '2023-01-20',
#                '2023-01-21', '2023-01-22', '2023-01-23', '2023-01-24',
#                '2023-01-25', '2023-01-26', '2023-01-27', '2023-01-28',
#                '2023-01-29', '2023-01-30', '2023-01-31', '2023-02-01',
#                '2023-02-02', '2023-02-03', '2023-02-04', '2023-02-05',
#                '2023-02-06', '2023-02-07', '2023-02-08', '2023-02-09',
#                '2023-02-10', '2023-02-11', '2023-02-12', '2023-02-13',
#                '2023-02-14', '2023-02-15', '2023-02-16', '2023-02-17',
#                '2023-02-18', '2023-02-19', '2023-02-20', '2023-02-21',
# ...

# %%
ts_data
# Out:
#          date     value category
# 0  2023-01-01  1.096192        B
# 1  2023-01-02  0.063780        C
# 2  2023-01-03 -1.380983        C
# 3  2023-01-04 -0.567763        B
# 4  2023-01-05 -1.005504        A
# ..        ...       ...      ...
# 95 2023-04-06 -9.464976        C
# 96 2023-04-07 -8.145877        A
# 97 2023-04-08 -7.084195        C
# 98 2023-04-09 -7.203496        B
# 99 2023-04-10 -6.633168        A
#
# [100 rows x 3 columns]

# %%
ts_data.dtypes
# Out:
# date        datetime64[ns]
# value              float64
# category            object
# dtype: object

# %%
ts_data['date'] = pd.to_datetime(ts_data['date'])

# %%
ts_data
# Out:
#          date     value category
# 0  2023-01-01  1.096192        B
# 1  2023-01-02  0.063780        C
# 2  2023-01-03 -1.380983        C
# 3  2023-01-04 -0.567763        B
# 4  2023-01-05 -1.005504        A
# ..        ...       ...      ...
# 95 2023-04-06 -9.464976        C
# 96 2023-04-07 -8.145877        A
# 97 2023-04-08 -7.084195        C
# 98 2023-04-09 -7.203496        B
# 99 2023-04-10 -6.633168        A
#
# [100 rows x 3 columns]

# %%
ts_data.dtypes
# Out:
# date        datetime64[ns]
# value              float64
# category            object
# dtype: object

# %%
ts_data = ts_data.set_index('date')

# %%
ts_data
# Out:
#                value category
# date
# 2023-01-01  1.096192        B
# 2023-01-02  0.063780        C
# 2023-01-03 -1.380983        C
# 2023-01-04 -0.567763        B
# 2023-01-05 -1.005504        A
# ...              ...      ...
# 2023-04-06 -9.464976        C
# 2023-04-07 -8.145877        A
# 2023-04-08 -7.084195        C
# 2023-04-09 -7.203496        B
# 2023-04-10 -6.633168        A
#
# [100 rows x 2 columns]

# %%
df_sales.set_index("Quarter")
# Out:
#         Region Product  Sales  Profit
# Quarter
# Q1       North       A    100      20
# Q3       South       A    150      30
# Q1        East       B    200      40
# Q1        West       B    120      25
# Q2       North       A    180      35
# Q3       South       B    160      32
# Q2        East       A    140      28
# Q2        West       B    190      38

# %%
ts_data['year'] = ts_data.index.year

# %%
ts_data
# Out:
#                value category  year
# date
# 2023-01-01  1.096192        B  2023
# 2023-01-02  0.063780        C  2023
# 2023-01-03 -1.380983        C  2023
# 2023-01-04 -0.567763        B  2023
# 2023-01-05 -1.005504        A  2023
# ...              ...      ...   ...
# 2023-04-06 -9.464976        C  2023
# 2023-04-07 -8.145877        A  2023
# 2023-04-08 -7.084195        C  2023
# 2023-04-09 -7.203496        B  2023
# 2023-04-10 -6.633168        A  2023
#
# [100 rows x 3 columns]

# %%
ts_data['month'] = ts_data.index.month

# %%
ts_data['day'] = ts_data.index.day

# %%
ts_data['weekday'] = ts_data.index.dayofweek

# %%
ts_data['quarter'] = ts_data.index.quarter

# %%
ts_data
# Out:
#                value category  year  month  day  weekday  quarter
# date
# 2023-01-01  1.096192        B  2023      1    1        6        1
# 2023-01-02  0.063780        C  2023      1    2        0        1
# 2023-01-03 -1.380983        C  2023      1    3        1        1
# 2023-01-04 -0.567763        B  2023      1    4        2        1
# 2023-01-05 -1.005504        A  2023      1    5        3        1
# ...              ...      ...   ...    ...  ...      ...      ...
# 2023-04-06 -9.464976        C  2023      4    6        3        2
# 2023-04-07 -8.145877        A  2023      4    7        4        2
# 2023-04-08 -7.084195        C  2023      4    8        5        2
# 2023-04-09 -7.203496        B  2023      4    9        6        2
# 2023-04-10 -6.633168        A  2023      4   10        0        2
#
# [100 rows x 7 columns]
