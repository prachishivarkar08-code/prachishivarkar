# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df1 = pd.read_excel("F:\\Dataset\\25. Order.xlsx")

# %%
df.to_json("newfile.json")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    orderID customerID  employeeID            orderDate         requiredDate  \
# 0    10248      VINET           5  1996-07-04 00:00:00  1996-08-01 00:00:00
# 1    10249      TOMSP           6  1996-07-05 00:00:00  1996-08-16 00:00:00
# 2    10250      HANAR           4  1996-07-08 00:00:00  1996-08-05 00:00:00
# 3    10251      VICTE           3  1996-07-08 00:00:00  1996-08-05 00:00:00
# 4    10252      SUPRD           4  1996-07-09 00:00:00  1996-08-06 00:00:00
#
#   shippedDate  shipVia  freight                   shipName  \
# 0  1996-07-16        3    32.38  Vins et alcools Chevalier
# 1  1996-07-10        1    11.61        Toms SpezialitÃ¤ten
# 2  1996-07-12        2    65.83              Hanari Carnes
# 3  1996-07-15        1    41.34       Victuailles en stock
# 4  1996-07-11        2    51.30         SuprÃªmes dÃ©lices
#
#            shipAddress        shipCity shipRegion shipPostalCode shipCountry
# ...

# %%
df.shape
# Out:
# (838, 14)

# %%
df.size
# Out:
# 11732

# %%
df.tail()
# Out:
#      orderID customerID  employeeID orderDate requiredDate shippedDate  \
# 833    11073      PERIC           2     35920        35948         NaT
# 834    11074      SIMOB           7     35921        35949         NaT
# 835    11075      RICSU           8     35921        35949         NaT
# 836    11076      BONAP           4     35921        35949         NaT
# 837    11077      RATTC           1     35921        35949         NaT
#
#      shipVia  freight                    shipName               shipAddress  \
# 833        2    24.95  Pericles Comidas clÃ¡sicas  Calle Dr. Jorge Cash 321
# 834        2    18.44               Simons bistro             VinbÃ¦ltet 34
# 835        2     6.19          Richter Supermarkt               Starenweg 5
# 836        2    38.28                    Bon app'       12 rue des Bouchers
# 837        2     8.53  Rattlesnake Canyon Grocery           2817 Milton Dr.
#
#          shipCity shipRegion shipPostalCode  shipCountry
# ...

# %%
df.sample(5)
# Out:
#      orderID customerID  employeeID            orderDate         requiredDate  \
# 139    10387      SANTG           1  1996-12-18 00:00:00  1997-01-15 00:00:00
# 337    10585      WELLI           7  1997-07-01 00:00:00  1997-07-29 00:00:00
# 505    10753      FRANS           3  1997-11-25 00:00:00  1997-12-23 00:00:00
# 173    10421      QUEDE           8  1997-01-21 00:00:00  1997-03-04 00:00:00
# 121    10369      SPLIR           8  1996-12-02 00:00:00  1996-12-30 00:00:00
#
#     shippedDate  shipVia  freight                shipName  \
# 139  1996-12-20        2    93.63          SantÃ© Gourmet
# 337  1997-07-10        1    13.41  Wellington Importadora
# 505  1997-11-27        1     7.70          Franchi S.p.A.
# 173  1997-01-27        1    99.23            Que DelÃ­cia
# 121  1996-12-09        2   195.68   Split Rail Beer & Ale
#
#                 shipAddress        shipCity shipRegion shipPostalCode  \
# 139  Erling Skakkes gate 78         Stavern        NaN           4110
# ...

# %%
len(df.columns)
# Out:
# 14

# %%
df.columns
# Out:
# Index(['orderID', 'customerID', 'employeeID', 'orderDate', 'requiredDate',
#        'shippedDate', 'shipVia', 'freight', 'shipName', 'shipAddress',
#        'shipCity', 'shipRegion', 'shipPostalCode', 'shipCountry'],
#       dtype='object')

# %%
type(df.shipName)
# Out:
# pandas.core.series.Series

# %%
df[["shipRegion", "shipCountry", "customerID"]]
# Out:
#     shipRegion  shipCountry customerID
# 0          NaN       France      VINET
# 1          NaN      Germany      TOMSP
# 2           RJ       Brazil      HANAR
# 3          NaN       France      VICTE
# 4          NaN      Belgium      SUPRD
# ..         ...          ...        ...
# 833        NaN       Mexico      PERIC
# 834        NaN      Denmark      SIMOB
# 835        NaN  Switzerland      RICSU
# 836        NaN       France      BONAP
# 837         NM          USA      RATTC
#
# [838 rows x 3 columns]

# %%
df.dtypes
# Out:
# orderID                    int64
# customerID                object
# employeeID                 int64
# orderDate                 object
# requiredDate              object
# shippedDate       datetime64[ns]
# shipVia                    int64
# freight                  float64
# shipName                  object
# shipAddress               object
# shipCity                  object
# shipRegion                object
# shipPostalCode            object
# shipCountry               object
# dtype: object

# %%
df.describe()
# Out:
#             orderID  employeeID                    shippedDate     shipVia  \
# count    838.000000  838.000000                            809  838.000000
# mean   10666.423628    4.396181  1997-08-09 23:45:45.611866368    2.004773
# min    10248.000000    1.000000            1996-07-10 00:00:00    1.000000
# 25%    10457.250000    2.000000            1997-02-28 00:00:00    1.000000
# 50%    10666.500000    4.000000            1997-09-09 00:00:00    2.000000
# 75%    10875.750000    7.000000            1998-02-04 00:00:00    3.000000
# max    11077.000000    9.000000            1998-05-06 00:00:00    3.000000
# std      241.924178    2.500769                            NaN    0.777507
#
#            freight
# count   838.000000
# mean     78.084308
# min       0.020000
# 25%      13.332500
# 50%      40.370000
# 75%      91.430000
# max    1007.640000
# std     116.527350

# %%
df.describe(include="all").T
# Out:
#                 count unique                  top  freq  \
# orderID         838.0    NaN                  NaN   NaN
# customerID        838     89                SAVEA    31
# employeeID      838.0    NaN                  NaN   NaN
# orderDate         838    482  1998-02-26 00:00:00     6
# requiredDate      838    456  1998-03-26 00:00:00     7
# shippedDate       809    NaN                  NaN   NaN
# shipVia         838.0    NaN                  NaN   NaN
# freight         838.0    NaN                  NaN   NaN
# shipName          838     90   Save-a-lot Markets    31
# shipAddress       838     89      187 Suffolk Ln.    31
# shipCity          838     70       Rio de Janeiro    34
# shipRegion        325     19                   SP    49
# shipPostalCode  819.0   83.0              83720.0  31.0
# shipCountry       838     21                  USA   123
#
#                                          mean                  min  \
# ...

# %%
df.describe(include="O")
# Out:
#        customerID            orderDate         requiredDate  \
# count         838                  838                  838
# unique         89                  482                  456
# top         SAVEA  1998-02-26 00:00:00  1998-03-26 00:00:00
# freq           31                    6                    7
#
#                   shipName      shipAddress        shipCity shipRegion  \
# count                  838              838             838        325
# unique                  90               89              70         19
# top     Save-a-lot Markets  187 Suffolk Ln.  Rio de Janeiro         SP
# freq                    31               31              34         49
#
#         shipPostalCode shipCountry
# count              819         838
# unique              83          21
# top              83720         USA
# freq                31         123

# %%
df.drop(0,inplace=True)

# %%
df.drop("orderID", axis=1, inplace=True )

# %%
df
# Out:
#     customerID  employeeID            orderDate         requiredDate  \
# 1        TOMSP           6  1996-07-05 00:00:00  1996-08-16 00:00:00
# 2        HANAR           4  1996-07-08 00:00:00  1996-08-05 00:00:00
# 3        VICTE           3  1996-07-08 00:00:00  1996-08-05 00:00:00
# 4        SUPRD           4  1996-07-09 00:00:00  1996-08-06 00:00:00
# 5        HANAR           3  1996-07-10 00:00:00  1996-07-24 00:00:00
# ..         ...         ...                  ...                  ...
# 833      PERIC           2                35920                35948
# 834      SIMOB           7                35921                35949
# 835      RICSU           8                35921                35949
# 836      BONAP           4                35921                35949
# 837      RATTC           1                35921                35949
#
#     shippedDate  shipVia  freight                    shipName  \
# 1    1996-07-10        1    11.61         Toms SpezialitÃ¤ten
# ...

# %%
df = df.drop("customerID", axis=1)

# %%
df.head()
# Out:
#    employeeID            orderDate         requiredDate shippedDate  shipVia  \
# 1           6  1996-07-05 00:00:00  1996-08-16 00:00:00  1996-07-10        1
# 2           4  1996-07-08 00:00:00  1996-08-05 00:00:00  1996-07-12        2
# 3           3  1996-07-08 00:00:00  1996-08-05 00:00:00  1996-07-15        1
# 4           4  1996-07-09 00:00:00  1996-08-06 00:00:00  1996-07-11        2
# 5           3  1996-07-10 00:00:00  1996-07-24 00:00:00  1996-07-16        2
#
#    freight              shipName          shipAddress        shipCity  \
# 1    11.61   Toms SpezialitÃ¤ten        Luisenstr. 48        MÃ¼nster
# 2    65.83         Hanari Carnes      Rua do PaÃ§o 67  Rio de Janeiro
# 3    41.34  Victuailles en stock    2 rue du Commerce            Lyon
# 4    51.30    SuprÃªmes dÃ©lices  Boulevard Tirou 255       Charleroi
# 5    58.17         Hanari Carnes      Rua do PaÃ§o 67  Rio de Janeiro
#
#   shipRegion shipPostalCode shipCountry
# 1        NaN          44087     Germany
# ...

# %%
df.isnull().sum()
# Out:
# employeeID          0
# orderDate           0
# requiredDate        0
# shippedDate        29
# shipVia             0
# freight             0
# shipName            0
# shipAddress         0
# shipCity            0
# shipRegion        512
# shipPostalCode     19
# shipCountry         0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 560

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df["shippedDate"].isnull().sum()
# Out:
# 29

# %%
df["shippedDate"].mode
# Out:
# <bound method Series.mode of 1     1996-07-10
# 2     1996-07-12
# 3     1996-07-15
# 4     1996-07-11
# 5     1996-07-16
#          ...
# 833          NaT
# 834          NaT
# 835          NaT
# 836          NaT
# 837          NaT
# Name: shippedDate, Length: 837, dtype: datetime64[ns]>

# %%
df["shippedDate"]= df["shippedDate"].fillna("1997-12-30")

# %%
df["shippedDate"]
# Out:
# 1     1996-07-10
# 2     1996-07-12
# 3     1996-07-15
# 4     1996-07-11
# 5     1996-07-16
#          ...
# 833   1997-12-30
# 834   1997-12-30
# 835   1997-12-30
# 836   1997-12-30
# 837   1997-12-30
# Name: shippedDate, Length: 837, dtype: datetime64[ns]

# %%
data = [10, 20, 30, 40, 50]
series = pd.Series(data, index=['a', 'b', 'c', 'd', 'e'])
print(series)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
data_dict = {'A': 100, 'B': 200, 'C': 300}
series_dict = pd.Series(data_dict)
print(series_dict)
# Out:
# A    100
# B    200
# C    300
# dtype: int64

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'Diana'],
    'Age': [25, 30, 35, 28],
    'City': ['New York', 'London', 'Tokyo', 'Paris'],
    'Salary': [70000, 80000, 90000, 75000]
}
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age      City  Salary
# 0    Alice   25  New York   70000
# 1      Bob   30    London   80000
# 2  Charlie   35     Tokyo   90000
# 3    Diana   28     Paris   75000

# %%
data_list = [['Alice', 25, 70000], ['Bob', 30, 80000]]

df_list = pd.DataFrame(data_list, columns=['Name', 'Age', 'Salary'])
print(df_list)
# Out:
#     Name  Age  Salary
# 0  Alice   25   70000
# 1    Bob   30   80000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 838 entries, 0 to 837
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   orderID         838 non-null    int64
#  1   customerID      838 non-null    object
#  2   employeeID      838 non-null    int64
#  3   orderDate       838 non-null    object
#  4   requiredDate    838 non-null    object
#  5   shippedDate     809 non-null    datetime64[ns]
#  6   shipVia         838 non-null    int64
#  7   freight         838 non-null    float64
#  8   shipName        838 non-null    object
#  9   shipAddress     838 non-null    object
#  10  shipCity        838 non-null    object
#  11  shipRegion      325 non-null    object
#  12  shipPostalCode  819 non-null    object
#  13  shipCountry     838 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(3), object(9)
# memory usage: 91.8+ KB

# %%
df.index
# Out:
# RangeIndex(start=0, stop=838, step=1)

# %%
import numpy as np
np.random.seed(42)
df = pd.DataFrame({
    'A': np.random.randn(100),
    'B': np.random.randint(1, 10, 100),
    'C': np.random.choice(['X', 'Y', 'Z'], 100),
    'D': pd.date_range('2023-01-01', periods=100, freq='D'),
    'E': np.random.randn(100) * 100
})

# %%
df.head()
# Out:
#           A  B  C          D           E
# 0  0.496714  9  Y 2023-01-01   23.229616
# 1 -0.138264  5  Y 2023-01-02   17.618092
# 2  0.647689  1  Y 2023-01-03 -115.256537
# 3  1.523030  3  Y 2023-01-04 -150.076839
# 4 -0.234153  8  Z 2023-01-05   16.502280

# %%
# Individual statistics
print(df['A'].mean())       # Mean

print(df['A'].median())     # Median

print(df['A'].mode())       # Mode

print(df['A'].std())        # Standard deviation

print(df['A'].var())        # Variance

print(df['A'].min())        # Minimum

print(df['A'].max())        # Maximum

print(df['A'].quantile(0.25))  # 25th percentile
# Out:
# -0.10384651739409384
# -0.1269562917797126
# 0    -2.619745
# 1    -1.987569
# 2    -1.959670
# 3    -1.913280
# 4    -1.763040
#         ...
# 95    1.523030
# 96    1.538037
# 97    1.564644
# 98    1.579213
# 99    1.852278
# Name: A, Length: 100, dtype: float64
# 0.9081684280078008
# 0.8247698936301602
# -2.6197451040897444
# 1.8522781845089378
# -0.6009056704964529

# %%
print(df['A'].quantile(0.25))  # 25th percentile
# Out:
# -0.6009056704964529

# %%
print(df['C'].value_counts())    # Count of unique values
# Out:
# C
# X    36
# Y    35
# Z    29
# Name: count, dtype: int64

# %%
print(df['C'].nunique())         # Number of unique values
# Out:
# 3

# %%
print(df.notnull().sum())        # Count of non-missing values
# Out:
# A    100
# B    100
# C    100
# D    100
# E    100
# dtype: int64

# %%
df1.head()
# Out:
#    orderID customerID  employeeID            orderDate         requiredDate  \
# 0    10248      VINET           5  1996-07-04 00:00:00  1996-08-01 00:00:00
# 1    10249      TOMSP           6  1996-07-05 00:00:00  1996-08-16 00:00:00
# 2    10250      HANAR           4  1996-07-08 00:00:00  1996-08-05 00:00:00
# 3    10251      VICTE           3  1996-07-08 00:00:00  1996-08-05 00:00:00
# 4    10252      SUPRD           4  1996-07-09 00:00:00  1996-08-06 00:00:00
#
#   shippedDate  shipVia  freight                   shipName  \
# 0  1996-07-16        3    32.38  Vins et alcools Chevalier
# 1  1996-07-10        1    11.61        Toms SpezialitÃ¤ten
# 2  1996-07-12        2    65.83              Hanari Carnes
# 3  1996-07-15        1    41.34       Victuailles en stock
# 4  1996-07-11        2    51.30         SuprÃªmes dÃ©lices
#
#            shipAddress        shipCity shipRegion shipPostalCode shipCountry
# ...

# %%
df.loc[20:40:4, ["shipVia","customerID",  "shipCity"]]
# Out:
#     shipVia customerID        shipCity
# 20        3      GROSR         Caracas
# 24        2      RATTC     Albuquerque
# 28        3      TORTU    MÃ©xico D.F.
# 32        1      BERGS          LuleÃ¥
# 36        1      LEHMS  Frankfurt a.M.
# 40        1      REGGC   Reggio Emilia

# %%
df.iloc[10:100:10,2:7]
# Out:
#     employeeID            orderDate         requiredDate shippedDate  shipVia
# 10           1  1996-07-17 00:00:00  1996-08-14 00:00:00  1996-07-23        1
# 20           8  1996-07-30 00:00:00  1996-08-27 00:00:00  1996-08-02        3
# 30           8  1996-08-12 00:00:00  1996-09-09 00:00:00  1996-08-16        2
# 40           4  1996-08-23 00:00:00  1996-09-20 00:00:00  1996-09-03        1
# 50           6  1996-09-05 00:00:00  1996-10-03 00:00:00  1996-09-11        2
# 60           7  1996-09-18 00:00:00  1996-10-16 00:00:00  1996-09-24        3
# 70           8  1996-10-01 00:00:00  1996-10-29 00:00:00  1996-10-04        2
# 80           4  1996-10-14 00:00:00  1996-11-11 00:00:00  1996-10-17        3
# 90           4  1996-10-25 00:00:00  1996-11-22 00:00:00  1996-10-29        3

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'Diana', 'Eve'],
    'Age': [25, 30, 35, 28, 32],
    'Department': ['HR', 'IT', 'Finance', 'HR', 'IT'],
    'Salary': [70000, 80000, 90000, 75000, 85000]
}
df = pd.DataFrame(data, index=['emp1', 'emp2', 'emp3', 'emp4', 'emp5'])

# %%
df
# Out:
#          Name  Age Department  Salary
# emp1    Alice   25         HR   70000
# emp2      Bob   30         IT   80000
# emp3  Charlie   35    Finance   90000
# emp4    Diana   28         HR   75000
# emp5      Eve   32         IT   85000

# %%
df[df['Age'] > 30]
# Out:
#          Name  Age Department  Salary
# emp3  Charlie   35    Finance   90000
# emp5      Eve   32         IT   85000

# %%
mask
# Out:
# emp1    False
# emp2    False
# emp3     True
# emp4    False
# emp5     True
# Name: Age, dtype: bool

# %%
df[(df['Age'] > 25) & (df['Department'] == 'IT')]   # and
# Out:
#      Name  Age Department  Salary
# emp2  Bob   30         IT   80000
# emp5  Eve   32         IT   85000

# %%
df[(df['Age'] > 25) | (df['Department'] == 'IT')]   # or
# Out:
#          Name  Age Department  Salary
# emp2      Bob   30         IT   80000
# emp3  Charlie   35    Finance   90000
# emp4    Diana   28         HR   75000
# emp5      Eve   32         IT   85000

# %%
departments = ['HR', 'Finance']

print(df[df['Department'].isin(departments)])
# Out:
#          Name  Age Department  Salary
# emp1    Alice   25         HR   70000
# emp3  Charlie   35    Finance   90000
# emp4    Diana   28         HR   75000

# %%
df[df['Name'].str.contains('C')]    # Names containing 'A'
# Out:
#          Name  Age Department  Salary
# emp3  Charlie   35    Finance   90000

# %%
print(df.query('Age > 30'))
# Out:
#          Name  Age Department  Salary
# emp3  Charlie   35    Finance   90000
# emp5      Eve   32         IT   85000

# %%
print(df.query('Age > 30 and Department == "IT"'))
# Out:
#      Name  Age Department  Salary
# emp5  Eve   32         IT   85000
